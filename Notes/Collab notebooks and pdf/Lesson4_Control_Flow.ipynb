# %%
loop = True

while loop == True: 
  number_of_wheels = int(input("Enter an integer number: "))
  vehicle = "Vehicle not recogniced"
  if number_of_wheels == 1:
    vehicle = "monocycle"
  elif number_of_wheels == 2 or number_of_wheels == 3:
    vehicle = "bike"

  elif number_of_wheels == 4 :
    vehicle ="Car"

  elif number_of_wheels > 4:
    vehicle ="Truck"

  print (vehicle)

  
  finish_loop = (input("Enter True or False: "))
  if finish_loop == "True":
    loop = True
  if finish_loop == "False":
    loop = False
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-b7c607854258> in <module>
#       2
#       3 while loop == True:
# ----> 4   number_of_wheels = int(input("Enter an integer number: "))
#       5   vehicle = "Vehicle not recogniced"
#       6   if number_of_wheels == 1:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
# ...
